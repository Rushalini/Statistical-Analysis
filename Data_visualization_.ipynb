# %% [markdown]
# <a href="https://colab.research.google.com/github/Rushalini/Statistical-Analysis-with-Excel/blob/main/Data_visualization_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
price=[10,30,5,5,25]
sales=[5000,3500,2000,4500,2500]
print("Mean:",np.mean(price))
print("Median:",np.median(price))
print("Mode:",pd.Series(price).mode())
print("Variance:",np.var(price))
print("Standard Deviation:",np.std(price))
x=plt.title("Bar chart")
plt.xlabel("Price")
plt.ylabel("Sales")
plt.bar(price,sales)
plt.show()
x=plt.title("Scatter plot")
plt.xlabel("Price")
plt.ylabel("Sales")
plt.scatter(price,sales)
plt.show()
x=plt.title("Pie chart")
plt.pie(price,labels=price)
plt.show()
# Out:
# Mean: 15.0
# Median: 10.0
# Mode: 0    5
# dtype: int64
# Variance: 110.0
# Standard Deviation: 10.488088481701515
